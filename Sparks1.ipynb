# %%
#Import Libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
import xlrd

# %%
#Add dataframe
df = pd.read_csv("https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv")
X=df[['Hours']]
y=df['Scores']

# %%
#Graph for the given data
df.plot(x='Hours', y='Scores', style='o')  
plt.title('Hours vs. Scores')  
plt.xlabel('Hours')  
plt.ylabel('Scores')  
plt.show()

# %%
#Regression Model
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, random_state=2)
regressor = LinearRegression()
regressor.fit(X_train, y_train)
coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])
print(coeff_df)
y_pred = regressor.predict(X_test)
# Out:
#        Coefficient
# Hours     9.940615

# %%
#Accuracy and error
from sklearn.metrics import r2_score
print("R^2 error", r2_score(y_test,y_pred))
# Out:
# R^2 error 0.9735538080811826

# %%
#For time=9.25 hours
hours_pred=[[9.25]]
score_pred = regressor.predict(hours_pred)
print("Predicted score for 9.25 hours=",(score_pred))
# Out:
# Predicted score for 9.25 hours= [93.45860056]
